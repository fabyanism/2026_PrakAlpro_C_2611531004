# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMROGRAMAN**
#
# **“Struktur Percabangan pada Python”**
#
# **Disusun Oleh :**
#
# **Fabian Alhadi Zalinov**
#
# **2611531004**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya sehingga laporan praktikum Pemrograman Python dengan judul "Struktur Percabangan pada Python" ini dapat diselesaikan dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta memperdalam pemahaman mengenai konsep dasar pemrograman Python, khususnya tentang  pengenalan berbagai struktur percabangan menggunakan bahasa Python.
#
# Penyusun menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi kesempurnaan laporan ini di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# Padang, 2026
#
# Fabian Alhadi Zalinov

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam pengembangan program komputer, kemampuan untuk mengambil keputusan berdasarkan suatu kondisi merupakan salah satu konsep dasar yang sangat penting dan menjadi fondasi bagi hampir seluruh logika program yang lebih kompleks. Struktur percabangan (*conditional statement*) memungkinkan program untuk mengeksekusi blok kode tertentu secara selektif berdasarkan nilai kebenaran suatu ekspresi logika, sehingga program dapat merespons berbagai kemungkinan input pengguna secara dinamis. Python menyediakan beberapa bentuk percabangan, mulai dari *if* tunggal, *if-else*, *if-elif-else*, hingga *match-case* yang diperkenalkan pada Python 3.10 sebagai alternatif *switch-case* pada bahasa pemrograman lain. Selain struktur kontrol tersebut, penguasaan operator logika seperti `and`, `or`, dan `!=` juga diperlukan untuk merangkai kondisi majemuk yang lebih kompleks.
#
# Praktikum ini mengangkat studi kasus Sistem Loket Terpadu dan Audit Transaksi Ekspedisi Wahana pada sebuah taman rekreasi, yang mengharuskan mahasiswa menerapkan seluruh bentuk percabangan tersebut secara terintegrasi, mulai dari validasi input menggunakan *if* tunggal, pemilihan paket wahana menggunakan *match-case*, evaluasi izin pengendara menggunakan *if-elif-else* dengan operator logika, hingga akumulasi diskon bertingkat menggunakan multi-*if* terpisah. Selain aspek pemrograman, praktikum ini juga melanjutkan pembiasaan penggunaan Git dan GitHub sebagai alat pengelolaan versi kode program dan sarana pengumpulan tugas.
#
# ## 1.2 Tujuan
# 1. Memahami konsep dan penerapan struktur percabangan *if* tunggal, *if-else*, dan *if-elif-else* dalam bahasa pemrograman Python.
# 2. Memahami penggunaan operator logika (`and`, `or`, `!=`) untuk menyusun kondisi majemuk pada program.
# 3. Memahami penerapan multi-*if* terpisah untuk mengakumulasikan beberapa kondisi diskon secara bertumpuk (bukan saling eksklusif seperti *elif*).
# 4. Memahami penggunaan struktur *match-case* sebagai alternatif percabangan berbasis pola (*pattern matching*).
# 5. Memahami cara mendokumentasikan hasil praktikum dalam bentuk laporan serta mengunggah hasil kerja ke repositori GitHub menggunakan alur *add*, *commit*, dan *push*.
#
# ## 1.3 Manfaat
#
# 1. Mahasiswa mampu merancang program Python yang mengambil keputusan berdasarkan berbagai kondisi input pengguna secara logis, terstruktur, dan sesuai dengan kaidah penulisan kode yang baik.
# 2. Mahasiswa memahami perbedaan penggunaan *if-elif-else*, multi-*if*, dan *match-case* sehingga dapat memilih struktur kontrol yang tepat sesuai kebutuhan kasus, serta terbiasa mendokumentasikan dan mengunggah hasil kerja ke GitHub sebagai bagian dari alur kerja kolaboratif.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1. **Percabangan (*Conditional Statement*)** Percabangan adalah struktur kontrol yang memungkinkan program mengeksekusi blok kode tertentu hanya jika suatu kondisi bernilai benar (`True`). Bentuk paling sederhana adalah *if* tunggal, yang hanya mengeksekusi satu blok kode ketika kondisinya terpenuhi tanpa alternatif lain. Bentuk *if-else* menambahkan blok alternatif yang dijalankan ketika kondisi bernilai salah. Adapun *if-elif-else* digunakan ketika terdapat lebih dari dua kemungkinan kondisi yang saling eksklusif, di mana Python akan mengevaluasi kondisi secara berurutan dan berhenti pada kondisi pertama yang terpenuhi.
#
# 2. **Operator Logika** Operator logika digunakan untuk menggabungkan atau membandingkan beberapa ekspresi kondisi sekaligus. Operator `and` bernilai benar hanya jika seluruh kondisi yang digabungkan bernilai benar, `or` bernilai benar jika salah satu kondisi terpenuhi, sedangkan `!=` digunakan untuk memeriksa ketidaksamaan dua nilai. Kombinasi operator ini memungkinkan penulisan kondisi majemuk, seperti pada validasi izin pengendara wahana yang mempertimbangkan umur dan kepemilikan SIM secara bersamaan.
#
# 3. **Multi-IF Terpisah (Non-*Elif*)** Berbeda dengan *elif* yang bersifat eksklusif (hanya satu blok yang dieksekusi), serangkaian pernyataan *if* independen memungkinkan setiap kondisi dievaluasi secara terpisah tanpa saling menggugurkan. Pola ini cocok digunakan untuk kasus akumulasi, misalnya penjumlahan beberapa jenis diskon yang masing-masing dapat berlaku secara bersamaan apabila syaratnya terpenuhi.
#
# 4. **Struktur *Match-Case*** *Match-case* merupakan bentuk *structural pattern matching* yang diperkenalkan pada Python 3.10 (PEP 634) sebagai alternatif yang lebih ringkas dibandingkan rangkaian *if-elif* panjang untuk kasus pencocokan nilai tunggal terhadap beberapa kemungkinan. Setiap `case` mewakili satu kemungkinan pola, sedangkan `case _` berfungsi sebagai kondisi *default* yang menangkap nilai apa pun yang tidak cocok dengan pola sebelumnya.
#
# 5. **Git dan GitHub** Git merupakan sistem *version control* terdistribusi yang digunakan untuk melacak perubahan pada kode program, sedangkan GitHub adalah platform daring yang menyimpan repositori Git dan menjadi pusat kolaborasi bagi pengembang di seluruh dunia. Proses menghubungkan proyek lokal ke repositori jarak jauh umumnya melibatkan tahapan penambahan perubahan (`git add`), pencatatan perubahan (`git commit`), dan pengunggahan ke repositori jarak jauh (`git push`).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "if1_2611531004.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama if1_2611531004.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1004
# Program ini menggunakan fungsi input()

ipk_1004 = float(input("Input IPK Anda = "))

if ipk_1004 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_1004))

print("Program Selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 4.0
# Program Selesai

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_1.jpg" width="400"><br>
# <em>Gambar 2.1 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk meminta pengguna memasukkan nilai IPK melalui input(), lalu mengubahnya menjadi tipe data desimal (float) dan menyimpannya ke variabel ipk_1004.
# 2. Bagian kedua berfungsi untuk memeriksa kondisi menggunakan if: jika nilai ipk_1004 lebih besar dari 2.75, maka program akan mencetak pesan kelulusan beserta nilai IPK yang diinput.
# 3. Bagian ketiga berfungsi untuk mencetak pesan "Program Selesai" yang akan selalu tampil di akhir, tidak peduli apakah kondisi if terpenuhi atau tidak.

# %% [markdown]
# ### 2.2.2 Program "if2_2611531004.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama if2_2611531004.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1004
# Program ini menggunakan fungsi input()

ipk_1004 = float(input("Input IPK Anda = "))

if ipk_1004 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_1004))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")
# Out:
# Anda Tidak Lulus
# Program Selesai

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_2.jpg" width="400"><br>
# <em>Gambar 2.2 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk meminta input IPK dari pengguna dan menyimpannya sebagai float ke variabel ipk_1004.
# 2. Bagian kedua berfungsi untuk mengecek kondisi if: jika ipk_1004 lebih besar dari 2.75, program mencetak pesan kelulusan dengan predikat sangat memuaskan.
# 3. Bagian ketiga berfungsi sebagai alternatif (else) dari kondisi di atas: jika ipk_1004 tidak lebih besar dari 2.75, maka program mencetak pesan "Anda Tidak Lulus".
# 4. Bagian keempat berfungsi untuk mencetak "Program Selesai" setelah salah satu dari kondisi if atau else dijalankan.

# %% [markdown]
# ### 2.2.3 Program "multi_if1__2611531004.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama multi_if1_261531004.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1004
# Program ini menggunakan fungsi input()

umur_1004 = int(input("Input umur anda: "))
sim_1004 = input("Apakah Anda Sudah Punya Sim C (y/t): ")[0]

if umur_1004 >= 17 and sim_1004 == 'y':
    print("Anda Sudah dewasa dan boleh bawa motor")

if umur_1004 >= 17 and sim_1004 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")

if umur_1004 < 17 and sim_1004 == 'y':
    print("Anda Belum Cukup Umur punya sim")

if umur_1004 < 17 and sim_1004 != 'y':
    print("Anda Belum Cukup Umur bawa motor")
# Out:
# Anda Sudah dewasa tetapi tidak boleh bawa motor

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_3.jpg" width="400"><br>
# <em>Gambar 2.3 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk meminta input umur pengguna (umur_1004) sebagai bilangan bulat, dan input status kepemilikan SIM C (sim_1004) sebagai satu karakter huruf pertama dari jawaban pengguna.
# 2. Bagian kedua berfungsi untuk memeriksa kondisi pertama: jika umur ≥ 17 dan sudah punya SIM ('y'), maka dicetak pesan bahwa pengguna sudah dewasa dan boleh membawa motor.
# 3. Bagian ketiga berfungsi untuk memeriksa kondisi kedua secara terpisah: jika umur ≥ 17 tetapi belum punya SIM, maka dicetak pesan bahwa pengguna sudah dewasa tapi tidak boleh membawa motor.
# 4. Bagian keempat berfungsi untuk memeriksa kondisi ketiga secara terpisah: jika umur < 17 dan sudah punya SIM, maka dicetak pesan bahwa pengguna belum cukup umur untuk punya SIM.
# 5. Bagian kelima berfungsi untuk memeriksa kondisi keempat secara terpisah: jika umur < 17 dan belum punya SIM, maka dicetak pesan bahwa pengguna belum cukup umur untuk membawa motor.

# %% [markdown]
# ### 2.2.4 Program "if_elif_else1_2611531004.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama if_elif_else1_261531004.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1004
# Program ini menggunakan fungsi input()

umur_1004 = int(input("Input umur anda: "))
sim_1004 = input("Apakah Anda Sudah Punya Sim C: ")[0]

if umur_1004 >= 17 and sim_1004 == 'y':
    print("Anda Sudah dewasa dan boleh bawa motor")
elif umur_1004 >= 17 and sim_1004 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")
elif umur_1004 < 17 and sim_1004 == 'y':
    print("Anda Belum Cukup Umur punya SIM")
else:
    print("Anda Belum Cukup Umur dan tidak boleh bawa motor")
print("Program Selesai")
# Out:
# Anda Sudah dewasa tetapi tidak boleh bawa motor
# Program Selesai

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_4.jpg" width="400"><br>
# <em>Gambar 2.4 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk meminta input umur (umur_1004) dan status kepemilikan SIM (sim_1004, diambil karakter pertamanya saja).
# 2. Bagian kedua berfungsi sebagai kondisi awal (if): jika umur ≥ 17 dan punya SIM, dicetak pesan boleh membawa motor.
# 3. Bagian ketiga berfungsi sebagai kondisi lanjutan pertama (elif): jika kondisi pertama tidak terpenuhi tapi umur ≥ 17 dan tidak punya SIM, dicetak pesan dewasa tapi tidak boleh membawa motor.
# 4. Bagian keempat berfungsi sebagai kondisi lanjutan kedua (elif): jika kondisi sebelumnya tidak terpenuhi tapi umur < 17 dan punya SIM, dicetak pesan belum cukup umur untuk punya SIM.
# 5. Bagian kelima berfungsi sebagai kondisi terakhir (else): jika semua kondisi di atas tidak terpenuhi (umur < 17 dan tidak punya SIM), dicetak pesan belum cukup umur dan tidak boleh membawa motor.
# 6. Bagian keenam berfungsi untuk mencetak "Program Selesai" setelah salah satu cabang di atas dijalankan.

# %% [markdown]
# ### 2.2.5 Program "multi_if2_2611531004.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama multi_if1_261531004.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: total_belanja_1004
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dari user
total_belanja_1004 = float(input("Masukkan total belanja (Rp): "))

# Input status member (mengecek apakah user mengetik 'y' atau 'ya')
input_member_1004 = input("Apakah Anda member? (y/t): ").strip().lower()
is_member_1004 = input_member_1004 in ["y", "ya"]

# Input status kode promo (mengecek apakah user mengetik 'y' atau 'ya')
input_promo_1004 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_1004 = input_promo_1004 in ["y", "ya"]

total_diskon_persen_1004 = 0

# Multi-IF terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi syarat sekaligus

if total_belanja_1004 > 1000000:
    total_diskon_persen_1004 += 10 # Diskon belanja besar

if is_member_1004:
    total_diskon_persen_1004 += 5 # Diskon member

if kode_promo_valid_1004:
    total_diskon_persen_1004 += 15 # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_1004 = total_belanja_1004 * (total_diskon_persen_1004 / 100)
total_bayar_1004 = total_belanja_1004 - nominal_diskon_1004

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon    : {total_diskon_persen_1004}% (Rp {nominal_diskon_1004:,.0f})")
print(f"Total Bayar     : Rp {total_bayar_1004:,.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_1004}%")
# Output: Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promo valid
# Out:
# --- Rincian Pembayaran ---
# Total Diskon    : 20% (Rp 60,000)
# Total Bayar     : Rp 240,000
# Total diskon yang Anda dapatkan: 20%

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_5.jpg" width="400"><br>
# <em>Gambar 2.5 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk meminta input total belanja (total_belanja_1004) sebagai float.
# 2. Bagian kedua berfungsi untuk meminta input status member dan mengubahnya menjadi nilai boolean (is_member_1004) — bernilai True jika pengguna mengetik "y" atau "ya".
# 3. Bagian ketiga berfungsi untuk meminta input validitas kode promo dan mengubahnya menjadi boolean (kode_promo_valid_1004) dengan cara serupa.
# 4. Bagian keempat berfungsi untuk menyiapkan variabel total_diskon_persen_1004 dengan nilai awal 0, sebagai penampung akumulasi persentase diskon.
# 5. Bagian kelima berfungsi untuk mengevaluasi tiga kondisi if secara independen (bukan elif): jika belanja > Rp1.000.000 tambahkan diskon 10%, jika member tambahkan diskon 5%, dan jika kode promo valid tambahkan diskon 15% — sehingga diskon bisa menumpuk jika beberapa syarat terpenuhi sekaligus.
# 6. Bagian keenam berfungsi untuk menghitung nominal diskon (nominal_diskon_1004) dan total yang harus dibayar (total_bayar_1004) berdasarkan total persentase diskon yang terkumpul.
# 7. Bagian ketujuh berfungsi untuk menampilkan rincian pembayaran, yaitu persentase & nominal diskon serta total akhir yang harus dibayar pengguna.

# %% [markdown]
# ### 2.2.6 Program "nilai_2611531004.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama nilai_261531004.py
# Buat program untuk nested if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1004
# Program ini menggunakan fungsi input()
# Program konversi nilai angka menjadi huruf

nilai_1004 = int(input("Inputkan nilai angka= "))

if nilai_1004 >= 81:
    print("A")
elif nilai_1004 >= 70:
    print("B")
elif nilai_1004 >= 60:
    print("C")
elif nilai_1004 >= 50:
    print("D")
else:
    print("E")
# Out:
# B

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_6.jpg" width="400"><br>
# <em>Gambar 2.6 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk meminta input nilai angka dari pengguna (nilai_1004) sebagai bilangan bulat.
# 2. Bagian kedua berfungsi untuk memeriksa kondisi bertingkat menggunakan if-elif-else: jika nilai ≥ 81 dicetak "A"; jika tidak, dicek apakah ≥ 70 untuk "B"; jika tidak, dicek apakah ≥ 60 untuk "C"; jika tidak, dicek apakah ≥ 50 untuk "D"; dan jika semua syarat di atas tidak terpenuhi maka dicetak "E" sebagai nilai default (else).

# %% [markdown]
# ### 2.2.7 Program "match_case1_2611531004.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama match_case1.py
# Buat program untuk match case
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1004
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_1004 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_1004:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# Juli

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_7.jpg" width="400"><br>
# <em>Gambar 2.7 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk meminta input angka bulan (1–12) dari pengguna dan menyimpannya sebagai bilangan bulat ke variabel bulan_1004.
# 2. Bagian kedua berfungsi untuk mencocokkan nilai bulan_1004 menggunakan struktur match-case: setiap case (1 sampai 12) akan mencetak nama bulan yang sesuai dengan angka yang diinput.
# 3. Bagian ketiga berfungsi sebagai penanganan kasus default (case _): jika angka yang dimasukkan tidak sesuai dengan 1–12, program akan mencetak pesan "Angka tidak valid".

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :** Studi Kasus: Sistem Loket Terpadu & Audit Transaksi Ekspedisi Wahana Sebuah wahana rekreasi petualangan membutuhkan sistem loket berbasis konsol untuk menentukan jenis wahana, memverifikasi kelaikan pengunjung dengan kondisi majemuk (logical operators), menghitung diskon akumulatif menggunakan multi-if terpisah, serta mencetak audit status operasional. Catatan Materi: Seluruh alur program disusun murni menggunakan 4 pilar percabangan yang diajarkan pada modul Pekan 4: (1) if tunggal, (2) if-else, (3) if-elif-else dengan operator logika (and, or, !=), (4) Multi-if terpisah untuk diskon akumulasi, dan (5) match-case (1 s.d. 5 beserta case _). Tidak ada nested-if (if di dalam if).

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas4_2611531004"

# %%
"""
Tugas Praktikum 4 - Algoritma Pemrograman
Studi Kasus: Sistem Loket Terpadu & Audit Transaksi Ekspedisi Wahana
Nama    : Fabian Alhadi Zalinov
NIM     : 2611531004
Kelas   : C
"""

print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")

# 1. Input Data Pengunjung & String Handling
nama_1004 = input("Masukkan Nama Pengunjung : ")
umur_1004 = int(input("Input umur anda : "))
sim_1004 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()[0]

# 2. Pemilihan Wahana menggunakan match-case (case 1-5 dan default _)
print("Pilihan Paket Wahana (1-5):")
print("1. Safari Rimba (Rp 50,000)")
print("2. Arung Jeram (Rp 75,000)")
print("3. Motor ATV Ekstrim (Rp 120,000)")
print("4. Roller Coaster Kilat (Rp 100,000)")
print("5. All-Access VIP (Rp 220,000)")
paket_1004 = int(input("Masukkan nomor paket (1-5) : "))

match paket_1004:
    case 1:
        nama_wahana_1004 = "Wahana Safari Rimba"
        harga_satuan_1004 = 50000
    case 2:
        nama_wahana_1004 = "Wahana Arung Jeram"
        harga_satuan_1004 = 75000
    case 3:
        nama_wahana_1004 = "Wahana Motor ATV Ekstrim"
        harga_satuan_1004 = 120000
    case 4:
        nama_wahana_1004 = "Wahana Roller Coaster Kilat"
        harga_satuan_1004 = 100000
    case 5:
        nama_wahana_1004 = "Wahana All-Access VIP"
        harga_satuan_1004 = 220000
    case _:
        print("Paket wahana tidak valid!")
        exit()

jumlah_tiket_1004 = int(input("Masukkan jumlah tiket : "))

# Validasi kelogisan jumlah tiket (if tunggal)
if jumlah_tiket_1004 <= 0:
    print("Peringatan: Kuota tiket tidak valid!")
    exit()

is_member_1004 = input("Apakah Anda member? (y/t) : ").strip().lower()
kode_promo_valid_1004 = input("Apakah kode promo valid? (y/t) : ").strip().lower()

# 3. Validasi Izin Kendali Wahana (if-elif-else dengan operator logika)
print("\n--- KELAYAKAN PENGENDARA WAHANA ---")
if paket_1004 == 3:
    if umur_1004 >= 17 and sim_1004 == 'y':
        print("Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.")
    elif umur_1004 >= 17 and sim_1004 != 'y':
        print("Status Akses: Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
    elif umur_1004 < 17 and sim_1004 == 'y':
        print("Status Akses: Identitas tidak valid: Belum cukup umur memiliki SIM.")
    else:
        print("Status Akses: Anda belum cukup umur dan tidak boleh bawa motor ATV.")
else:
    if umur_1004 >= 10:
        print(f"Status Akses: Anda memenuhi syarat umur untuk mengikuti {nama_wahana_1004}.")
    else:
        print(f"Status Akses: Maaf, Anda belum memenuhi syarat umur minimal untuk {nama_wahana_1004}.")

# 4. Akumulasi Diskon Bertingkat menggunakan Multi-IF terpisah
subtotal_1004 = harga_satuan_1004 * jumlah_tiket_1004
total_diskon_persen_1004 = 0

if subtotal_1004 >= 200000:
    total_diskon_persen_1004 += 10  # Diskon Belanja Besar

if is_member_1004 in ['y', 'ya']:
    total_diskon_persen_1004 += 5  # Diskon Member

if kode_promo_valid_1004 in ['y', 'ya']:
    total_diskon_persen_1004 += 15  # Diskon Voucher Promo

if jumlah_tiket_1004 >= 5:
    total_diskon_persen_1004 += 5  # Diskon Tambahan Rombongan

nominal_diskon_1004 = subtotal_1004 * (total_diskon_persen_1004 / 100)
total_bayar_1004 = subtotal_1004 - nominal_diskon_1004

# 5. Evaluasi Kelulusan Audit (if-else)
print("\n--- Rincian Pembayaran ---")
print(f"Subtotal Belanja : Rp {subtotal_1004:,.0f}")
print(f"Total Diskon     : {total_diskon_persen_1004}% (Rp {nominal_diskon_1004:,.0f})")
print(f"Total Bayar      : Rp {total_bayar_1004:,.0f}")

if total_bayar_1004 > 300000:
    print("Catatan Layanan : Selamat! Anda berhak mendapatkan Souvenir Gratis.")
else:
    print("Catatan Layanan : Terima kasih telah berkunjung.")

print("Program Selesai")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
# Pilihan Paket Wahana (1-5):
# 1. Safari Rimba (Rp 50,000)
# 2. Arung Jeram (Rp 75,000)
# 3. Motor ATV Ekstrim (Rp 120,000)
# 4. Roller Coaster Kilat (Rp 100,000)
# 5. All-Access VIP (Rp 220,000)
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).
#
# --- Rincian Pembayaran ---
# Subtotal Belanja : Rp 120,000
# Total Diskon     : 20% (Rp 24,000)
# Total Bayar      : Rp 96,000
# Catatan Layanan : Terima kasih telah berkunjung.
# Program Selesai

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_praktikum.jpg" width="400"><br>
# <em>Gambar 2.8 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas4_2611531004.py dirancang untuk mensimulasikan sistem loket sebuah wahana rekreasi, mulai dari pendataan pengunjung, pemilihan paket wahana, verifikasi kelayakan pengendara, hingga perhitungan diskon dan status akhir transaksi. Alur programnya sebagai berikut:
#
# 1. Input Data Pengunjung: Program meminta lima data dari pengguna melalui input(): nama pengunjung, umur (dikonversi ke int), status kepemilikan SIM C (diambil karakter pertama dan diubah ke huruf kecil menggunakan [0] dan .lower()), nomor paket wahana, serta jumlah tiket (dikonversi ke int).
# 2. Pemilihan Paket Wahana (match-case): Nomor paket yang diinput dievaluasi menggunakan struktur match-case dengan lima kondisi (case 1 sampai case 5), masing-masing menyimpan nama wahana dan harga satuannya ke variabel nama_wahana_1004 dan harga_satuan_1004. Apabila nomor paket di luar rentang 1–5, case _ akan mencetak pesan "Paket wahana tidak valid!" dan program dihentikan dengan exit().
# 3. Validasi Kelogisan Tiket (if tunggal): Setelah jumlah tiket diinput, dilakukan pengecekan if jumlah_tiket_1004 <= 0 untuk memastikan jumlah tiket bernilai logis. Jika tidak valid, program mencetak peringatan dan berhenti.
# 4. Validasi Izin Kendali Wahana (if-elif-else dengan operator logika): Khusus paket 3 (Motor ATV Ekstrim), kelayakan pengendara dievaluasi dengan kombinasi operator logika and dan != pada empat kondisi umur dan kepemilikan SIM (dewasa & ber-SIM, dewasa & tanpa SIM, di bawah umur & ber-SIM, serta di bawah umur & tanpa SIM). Untuk paket selain 3, digunakan if-else sederhana yang hanya memeriksa apakah umur pengunjung sudah mencapai minimal 10 tahun.
# 5. Akumulasi Diskon Bertingkat (Multi-if terpisah): Subtotal dihitung dari harga_satuan_1004 * jumlah_tiket_1004. Empat blok if independen (bukan elif) mengecek syarat diskon secara terpisah sehingga persentasenya bisa terakumulasi: diskon belanja besar (subtotal ≥ Rp200.000, +10%), diskon member (+5%), diskon voucher promo (+15%), dan diskon rombongan (jumlah tiket ≥ 5, +5%).
# 6. Evaluasi Akhir Transaksi (if-else): Nominal diskon dan total bayar dihitung dari total persentase diskon yang terkumpul. Kondisi if total_bayar_1004 > 300000 menentukan apakah pengunjung berhak mendapat souvenir gratis atau hanya menerima ucapan terima kasih. Seluruh rincian pembayaran ditampilkan menggunakan f-string dengan format desimal :,.0f agar angka rupiah tampil rapi dengan pemisah ribuan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa struktur percabangan merupakan salah satu konsep fundamental dalam pemrograman yang memungkinkan program mengambil keputusan secara dinamis berdasarkan kondisi input. Melalui studi kasus Sistem Loket Terpadu Ekspedisi Wahana, mahasiswa mempraktikkan seluruh bentuk percabangan secara terintegrasi, mulai dari *if* tunggal untuk validasi sederhana, *if-elif-else* dengan operator logika untuk evaluasi kondisi majemuk, multi-*if* terpisah untuk akumulasi diskon bertingkat, hingga *match-case* untuk pemilihan paket berbasis pola.
#
# Pemahaman terhadap perbedaan mendasar antara *elif* yang bersifat eksklusif dan multi-*if* yang bersifat akumulatif menjadi bekal penting bagi mahasiswa dalam merancang logika program yang sesuai dengan kebutuhan kasus nyata. Selain itu, praktikum ini juga memperkuat pembiasaan penggunaan Git dan GitHub sebagai sarana pengelolaan versi kode dan dokumentasi hasil kerja secara sistematis.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] A. Kadir, *Dasar Pemrograman Python 3*, Yogyakarta: Penerbit ANDI, 2018.
#
# [2] Python Software Foundation, "The Python Language Reference — The match statement," [Online]. Tersedia: https://docs.python.org/3/reference/compound_stmts.html#the-match-statement. [Diakses 25 September 2026].
#
# [3] S. Chacon dan B. Straub, *Pro Git*, edisi Bahasa Indonesia, [Online]. Tersedia: https://git-scm.com/book/id/v2. [Diakses 25 September 2026].
#
# [4] Python Software Foundation, "PEP 634 — Structural Pattern Matching: Specification," [Online]. Tersedia: https://peps.python.org/pep-0634/. [Diakses 25 September 2026].

# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMROGRAMAN**
#
# **“Operator pada Python”**
#
# **Disusun Oleh :**
#
# **Fabian Alhadi Zalinov**
#
# **2611531004**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya sehingga laporan praktikum Pemrograman Python dengan judul "Operator pada Python" ini dapat diselesaikan dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta memperdalam pemahaman mengenai konsep dasar pemrograman Python, khususnya tentang  pengenalan berbagai operasi dasar menggunakan bahasa Python.
#
# Penyusun menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi kesempurnaan laporan ini di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# Padang, 2026
#
# Fabian Alhadi Zalinov

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Setelah pada praktikum sebelumnya mahasiswa mempelajari dasar-dasar bahasa pemrograman Python, penggunaan editor Visual Studio Code, serta alur kerja version control dengan Git dan GitHub, praktikum kali ini membawa mahasiswa masuk ke tahap yang lebih mendalam, yaitu pemahaman terhadap operator dalam Python. Operator merupakan salah satu elemen fundamental dalam pemrograman karena hampir seluruh proses pengolahan data, mulai dari perhitungan sederhana hingga pengambilan keputusan yang kompleks, bergantung pada penggunaan operator yang tepat. Python menyediakan berbagai jenis operator, yaitu operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, dan bitwise, yang masing-masing memiliki fungsi dan konteks penggunaan tersendiri.
#
# Untuk mengaplikasikan pemahaman tersebut, praktikum ini menggunakan studi kasus berupa sistem simulasi transaksi dan validasi akses toko, di mana mahasiswa diminta membangun program kasir sederhana yang menghitung total transaksi pelanggan sekaligus memeriksa status keanggotaan dan kelayakan promo. Studi kasus ini dipilih karena merepresentasikan permasalahan nyata yang umum dijumpai dalam pengembangan perangkat lunak, sehingga mahasiswa tidak hanya memahami operator secara teoritis, tetapi juga mampu menerapkannya dalam satu alur logika program yang utuh dan terintegrasi.
#
# ## 1.2 Tujuan
# 1. Memahami berbagai jenis operator dalam Python, meliputi operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, dan bitwise.
# 2. Mampu menerapkan berbagai operator tersebut dalam satu studi kasus program simulasi transaksi dan validasi akses toko secara terintegrasi.
# 3. Memahami perbedaan mendasar antara operator identitas (`is`) yang membandingkan identitas objek dengan operator perbandingan (`==`) yang membandingkan nilai/isi objek.
# 4. Mampu menyusun program yang menerima input dari pengguna dan mengolahnya menjadi keluaran yang terstruktur menggunakan berbagai jenis operator.
# 5. Mampu mendokumentasikan hasil praktikum serta mengelola proyek menggunakan Git dan GitHub.
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat membangun program Python yang mengintegrasikan berbagai jenis operator dalam satu alur logika transaksi yang runtut dan mudah dipahami.
# 2. Mahasiswa memahami cara merepresentasikan status atau kondisi suatu data menggunakan operator bitwise dalam bentuk kode biner, sebagai bekal pemahaman logika pemrograman tingkat lanjut.
# 3. Mahasiswa mampu membedakan penggunaan operator perbandingan, logika, keanggotaan, dan identitas secara tepat sesuai konteks permasalahan yang dihadapi.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1. **Operator Aritmatika**
#     Operator aritmatika digunakan untuk melakukan perhitungan matematis, seperti penjumlahan (`+`), pengurangan (`-`), perkalian (`*`), pembagian (`/`), pembagian bulat (`//`), sisa pembagian atau modulus (`%`), dan pangkat (`**`). Dalam studi kasus transaksi, operator ini digunakan untuk menghitung total harga setelah diskon, harga rata-rata barang, serta besarnya potongan harga.
# 2. **Operator Perbandingan**
#    Operator perbandingan digunakan untuk membandingkan dua nilai dan menghasilkan tipe data boolean (`True` atau `False`). Operator ini meliputi `==`, `!=`, `>`, `<`, `>=`, dan `<=`. Dalam studi kasus, operator perbandingan digunakan untuk menentukan apakah total belanja pelanggan memenuhi syarat minimum diskon atau apakah jumlah barang memenuhi syarat promo tambahan.
# 3. **Operator Logika**
#    Operator logika (`and`, `or`, `not`) digunakan untuk menggabungkan atau membalikkan dua kondisi atau lebih menjadi satu hasil evaluasi boolean. Operator ini banyak digunakan pada pengambilan keputusan bertingkat, misalnya untuk menentukan apakah seorang pelanggan berhak atas diskon khusus karena berstatus member sekaligus memenuhi syarat minimum belanja.
# 4. **Operator Penugasan**
#    Operator penugasan digunakan untuk memberikan atau memperbarui nilai suatu variabel, seperti `=`, dan augmented assignment seperti `+=`, `-=`, `*=`, dan `/=`. Operator ini umum digunakan untuk memperbarui nilai total pembayaran atau akumulasi nilai lain di dalam program tanpa perlu menuliskan ulang nama variabel secara lengkap.
# 5. **Operator Keanggotaan (Membership)**
#    Operator `in` dan `not in` digunakan untuk memeriksa apakah suatu nilai terdapat di dalam sebuah struktur data, seperti list atau string. Dalam studi kasus, operator ini digunakan untuk memeriksa apakah kode promo yang dimasukkan pelanggan terdapat pada daftar kode promo yang tersedia.
# 6. **Operator Identitas (Identity)**
#    Operator `is` dan `is not` digunakan untuk membandingkan identitas dua objek, yaitu apakah keduanya menempati lokasi memori yang sama, berbeda dengan operator `==` yang membandingkan kesamaan nilai atau isi objek. Perbedaan ini penting dipahami agar mahasiswa tidak keliru menggunakan `is` sebagai pengganti `==` dalam pembandingan nilai.
# 7. **Operator Bitwise**
#    Operator bitwise (`&`, `|`, `^`, `~`, `<<`, `>>`) bekerja pada level bit dari suatu bilangan biner. Operator AND (`&`) digunakan untuk memeriksa apakah suatu kondisi terpenuhi, operator OR (`|`) digunakan untuk menggabungkan beberapa kondisi, dan operator XOR (`^`) digunakan untuk membandingkan perbedaan antara dua status. Dalam studi kasus, operator bitwise digunakan untuk merepresentasikan kombinasi status pelanggan (member, minimal belanja, minimal jumlah barang, dan ketersediaan promo) ke dalam satu kode status transaksi berbentuk biner.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "aritmatika_2611531004"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama aritmatika_2611531004.py
# Buat program untuk operator aritmatika dalam Phyton
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1004
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_1004 = int(input("Input angka-1: "))
angka2_1004 = int(input("Input angka-2: "))

# Penjumlahan
hasil_1004 = angka1_1004 + angka2_1004
print("\nOperator Penjumlahan")
print("Hasil =", hasil_1004)

# Pengurangan
hasil_1004 = angka1_1004 - angka2_1004
print("\nOperator Pengurangan")
print("Hasil =", hasil_1004)

# Perkalian
hasil = angka1_1004 * angka2_1004
print("\nOperator Perkalian")
print("Hasil =", hasil_1004)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_1004 != 0:
    hasil = angka1_1004 / angka2_1004
    print("\nOperator Pembagian")
    print("Hasil =", hasil_1004)

    hasil = angka1_1004 // angka2_1004
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_1004)

    hasil = angka1_1004 % angka2_1004
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_1004)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil = angka1_1004 ** angka2_1004
print("\nOperator Pangkat")
print("Hasil =", hasil_1004)
# Out:
# Operator Penjumlahan
# Hasil = 15
#
# Operator Pengurangan
# Hasil = 5
#
# Operator Perkalian
# Hasil = 5
#
# Operator Pembagian
# Hasil = 5
#
# Operator Pembagian Bulat
# Hasil = 5
#
# Operator Sisa Bagi
# Hasil = 5
#
# Operator Pangkat
# Hasil = 5

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_aritmatika.jpg" width="400"><br>
# <em>Gambar 2.1 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk menerima dua input angka dari pengguna (angka1_1004 dan angka2_1004) dan mengonversinya menjadi tipe data integer.
# 2. Bagian kedua berfungsi untuk menghitung penjumlahan kedua angka menggunakan operator + dan menampilkan hasilnya.
# 3. Bagian ketiga berfungsi untuk menghitung pengurangan kedua angka menggunakan operator -.
# 4. Bagian keempat berfungsi untuk menghitung perkalian kedua angka menggunakan operator *.
# 5. Bagian kelima berfungsi untuk menghitung pembagian biasa (/), pembagian bulat (//), dan sisa bagi/modulus (%), tetapi hanya dijalankan jika angka2_1004 tidak sama dengan 0 (untuk menghindari error pembagian dengan nol). Jika angka kedua bernilai 0, program menampilkan pesan peringatan.
# 6. Bagian keenam berfungsi untuk menghitung perpangkatan angka1 dipangkatkan angka2 menggunakan operator **.

# %% [markdown]
# ### 2.2.2 Program "assignment_2611531004"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama assignment_2611531004.py
# Nama variabel ditambah 4 digit nim terakhir contoh: nama_1004
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam Phyton

angka1_1004 = int(input("Input angka-1: "))
angka2_1004 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_1004)
print("Nilai awal angka2 =", angka2_1004)

# Assignment biasa
hasil_1004 = angka1_1004
print("\nAssignment biasa (=)")
print("Hasil =", hasil_1004)

# Assignment penambahan
hasil_1004 = angka1_1004
hasil_1004 += angka2_1004
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_1004)

# Assignment pengurangan
hasil_1004 = angka1_1004
hasil_1004 -= angka2_1004
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_1004)

# Assignment perkalian
hasil_1004 = angka1_1004
hasil_1004 *= angka2_1004
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_1004)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_1004 != 0:
    hasil_1004 = angka1_1004
    hasil_1004 /= angka2_1004
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_1004)
    # Operator tambahan
    hasil_1004 = angka1_1004
    hasil_1004 //= angka2_1004
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_1004)
    hasil_1004 = angka1_1004
    hasil_1004 %= angka2_1004
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_1004)
else:
    print("\nPembagian tidak dapat dilakukan")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_1004 = angka1_1004
hasil_1004 **= angka2_1004
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_1004)
# Out:
# Nilai awal angka1 = 10
# Nilai awal angka2 = 5
#
# Assignment biasa (=)
# Hasil = 10
#
# Assignment penambahan (+=)
# Hasil = 15
#
# Assignment pengurangan (-=)
# Hasil = 5
#
# Assignment perkalian (*=)
# Hasil = 50
#
# Assignment pembagian (/=)
# Hasil = 2.0
#
# Assignment pembagian bulat (//=)
# Hasil = 2
#
# Assignment sisa bagi (%=)
# Hasil = 0
#
# Assignment perpangkatan (**=)
# Hasil = 100000

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_assignment.jpg" width="400"><br>
# <em>Gambar 2.2 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk menerima dua input angka dan menampilkan nilai awal keduanya.
# 2. Bagian kedua berfungsi untuk mendemonstrasikan operator assignment biasa (=), yaitu menyalin nilai angka1_1004 ke hasil_1004.
# 3. Bagian ketiga sampai keenam berfungsi untuk mendemonstrasikan operator assignment gabungan: penambahan (+=), pengurangan (-=), dan perkalian (*=), masing-masing mereset hasil_1004 ke nilai angka1_1004 terlebih dahulu sebelum dioperasikan dengan angka2_1004.
# 4. Bagian ketujuh berfungsi untuk mendemonstrasikan operator assignment pembagian (/=), pembagian bulat (//=), dan sisa bagi (%=), dengan pengecekan agar angka2_1004 tidak bernilai 0.
# 5. Bagian terakhir berfungsi untuk mendemonstrasikan operator assignment perpangkatan (**=) sebagai operator tambahan.

# %% [markdown]
# ### 2.2.3 Program "bitwise_2611531004"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama bitwise_2611531004.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1004
# Program ini menggunakan fungsi input()

print("===================================")
print("1. OPERATOR BITWISE")
print("===================================")

angka1_1004 = int(input("Masukkan angka bitwise-1: "))
angka2_1004 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_1004, "| biner =", bin(angka1_1004))
print("angka2 =", angka2_1004, "| biner =", bin(angka2_1004))

# Bitwise AND
hasil_1004 = angka1_1004 & angka2_1004
print("\nBitwise AND (&)")
print(angka1_1004, "&", angka2_1004, "=", hasil_1004)
print("Biner hasil =", bin(hasil_1004))
print("Biner hasil (8 bit) =", format(hasil_1004, '08b'))

# Bitwise OR
hasil_1004 = angka1_1004 | angka2_1004
print("\nBitwise OR (|)")
print(angka1_1004, "|", angka2_1004, "=", hasil_1004)
print("Biner hasil =", bin(hasil_1004))
print("Biner hasil (8 bit) =", format(hasil_1004, '08b'))

# Bitwise XOR
hasil_1004 = angka1_1004 ^ angka2_1004
print("\nBitwise XOR (^)")
print(angka1_1004, "^", angka2_1004, "=", hasil_1004)
print("Biner hasil =", bin(hasil_1004))
print("Biner hasil (8 bit) =", format(hasil_1004, '08b'))

# Bitwise NOT
hasil_1004 = ~angka1_1004
print("\nBitwise NOT (~)")
print("~", angka1_1004, "=", hasil_1004)
print("Biner hasil =", bin(hasil_1004))
print("Biner hasil (8 bit) =", format(hasil_1004, '08b'))

# Bitwise geser kiri
jumlah_geser_1004 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_1004 = angka1_1004 << jumlah_geser_1004
print("\nBitwise geser kiri (<<)")
print(angka1_1004, "<<", jumlah_geser_1004, "=", hasil_1004)
print("Biner hasil =", bin(hasil_1004))
print("Biner hasil (8 bit) =", format(hasil_1004, '08b'))

# Bitwise geser kanan
hasil_1004 = angka1_1004 >> jumlah_geser_1004
print("\nBitwise geser kanan (>>)")
print(angka1_1004, ">>", jumlah_geser_1004, "=", hasil_1004)
print("Biner hasil =", bin(hasil_1004))
print("Biner hasil (8 bit) =", format(hasil_1004, '08b'))
# Out:
# ...
# 1. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1 = 10 | biner = 0b1010
# angka2 = 5 | biner = 0b101
#
# Bitwise AND (&)
# 10 & 5 = 0
# Biner hasil = 0b0
# Biner hasil (8 bit) = 00000000
#
# Bitwise OR (|)
# 10 | 5 = 15
# Biner hasil = 0b1111
# Biner hasil (8 bit) = 00001111
#
# Bitwise XOR (^)
# 10 ^ 5 = 15
# Biner hasil = 0b1111
# Biner hasil (8 bit) = 00001111
#
# Bitwise NOT (~)
# ~ 10 = -11
# Biner hasil = -0b1011
# Biner hasil (8 bit) = -0001011
#
# Bitwise geser kiri (<<)
# 10 << 2 = 40
# Biner hasil = 0b101000
# Biner hasil (8 bit) = 00101000
#
# Bitwise geser kanan (>>)
# 10 >> 2 = 2
# Biner hasil = 0b10
# Biner hasil (8 bit) = 00000010

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_bitwise1.jpg" width="400"><br>
# <img src="images/output_bitwise2.jpg" width="400"><br>
# <em>Gambar 2.3 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk menerima dua input angka dan menampilkan representasi biner keduanya menggunakan fungsi bin().
# 2. Bagian kedua berfungsi untuk menghitung operasi AND (&) bit demi bit antara kedua angka, lalu menampilkan hasil dalam desimal, biner, dan format biner 8-bit.
# 3. Bagian ketiga berfungsi untuk menghitung operasi OR (|) bit demi bit antara kedua angka.
# 4. Bagian keempat berfungsi untuk menghitung operasi XOR (^), yaitu bernilai 1 jika bit berbeda.
# 5. Bagian kelima berfungsi untuk menghitung operasi NOT (~) yang membalik semua bit dari angka1_1004 (hasilnya berupa komplemen dua, sehingga nilainya negatif).
# 6. Bagian keenam berfungsi untuk menerima input jumlah pergeseran bit, lalu menghitung operasi geser kiri (<<) yang menggandakan nilai sesuai jumlah pergeseran.
# 7. Bagian ketujuh berfungsi untuk menghitung operasi geser kanan (>>) yang membagi nilai (dibulatkan ke bawah) sesuai jumlah pergeseran.

# %% [markdown]
# ### 2.2.4 Program "logika_2611531004"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama logika_2611531004.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1004
# Program ini menggunakan fungsi input()
# Program operator logika dalam Phyton

# Memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_1004 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
a2_1004 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"

print("\nA1 =", a1_1004)
print("A2 =", a2_1004)

# Konjungsi: bernilai True jika keduanya True
hasil_1004 = a1_1004 and a2_1004
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_1004)

# Disjungsi: bernilai True jika salah satunya True
hasil_1004 = a1_1004 or a2_1004
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_1004)

# Negasi A1: membalikkan nilai A1
hasil_1004 = not a1_1004
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_1004)

# Negasi A2: membalikkan nilai A2
hasil_1004 = not a2_1004
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_1004)

#XOR: bernilai True jika kedua nilai berbeda
hasil_1004 = a1_1004 != a2_1004
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil_1004)
# Out:
# A1 = True
# A2 = False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = True
#
# Disjungsi Eksklusif (XOR)
# A1 XOR A2 = True

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_logika.jpg" width="400"><br>
# <em>Gambar 2.4 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk menerima dua input teks ("true"/"false"), lalu mengonversinya menjadi tipe data boolean menggunakan perbandingan == "true" setelah teks dirapikan (.strip().lower()).
# 2. Bagian kedua berfungsi untuk menghitung operator konjungsi (AND), yang bernilai True hanya jika kedua nilai boolean bernilai True.
# 3. Bagian ketiga berfungsi untuk menghitung operator disjungsi (OR), yang bernilai True jika salah satu nilai True.
# 4. Bagian keempat dan kelima berfungsi untuk menghitung operator negasi (NOT) pada masing-masing nilai A1 dan A2 secara terpisah, membalikkan nilai booleannya.
# 5. Bagian keenam berfungsi untuk menghitung operator XOR (disjungsi eksklusif) menggunakan operator !=, yang bernilai True jika kedua nilai boolean berbeda.

# %% [markdown]
# ### 2.2.5 Program "nama lainnya_2611531004"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama lainnya_2611531004.py
# Buat variabel ditambah 4 digit nim terakhir contoh: angka1_1004
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan identitas

print("===================================")
print("1. OPERATOR KEANGGOTAAN")
print("===================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_1004 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_1004 = [int(angka_1004.strip()) for angka_1004 in input_data_1004.split(",")]

nilai_dicari_1004 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_1004 = nilai_dicari_1004 in data_1004
print("\nOperator keanggotaan IN")
print(nilai_dicari_1004, "in", data_1004, "=", hasil_1004)

# Operator not in
hasil_1004 = nilai_dicari_1004 not in data_1004
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_1004, "not in", data_1004, "=", hasil_1004)


print("\n===================================")
print("2. OPERATOR IDENTITAS")
print("===================================")

# objek1 menggunakan list dari input pengguna
objek1_1004 = data_1004

# objek2 merujuk pada objek yang sama dengan objek1
objek2_1004 = objek1_1004

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_1004 = data_1004.copy()

print("objek1 =", objek1_1004)
print("objek2 =", objek2_1004)
print("objek3 =", objek3_1004)

# Operator is
hasil_1004 = objek1_1004 is objek2_1004
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_1004)

# Operator is not
hasil_1004 = objek1_1004 is not objek3_1004
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_1004)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai:")
print("objek1 is objek 3 = ", objek1_1004 is objek3_1004)
print("objek1 == objek 3 = ", objek1_1004 == objek3_1004)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 7 in [10, 9, 8, 7, 6, 5] = True
#
# Operator keanggotaan NOT IN
# 7 not in [10, 9, 8, 7, 6, 5] = False
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1 = [10, 9, 8, 7, 6, 5]
# objek2 = [10, 9, 8, 7, 6, 5]
# objek3 = [10, 9, 8, 7, 6, 5]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek3 = True
#
# Perbandingan identitas dan nilai:
# objek1 is objek 3 =  False
# objek1 == objek 3 =  True

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_namalainnya.jpg" width="400"><br>
# <em>Gambar 2.5 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk menerima input beberapa angka yang dipisahkan koma, lalu mengubahnya menjadi list integer menggunakan list comprehension dan split(",").
# 2. Bagian kedua berfungsi untuk menerima angka yang ingin dicari, lalu menggunakan operator keanggotaan in untuk mengecek apakah angka tersebut ada di dalam list.
# 3. Bagian ketiga berfungsi untuk menggunakan operator keanggotaan not in untuk mengecek apakah angka tersebut tidak ada di dalam list.
# 4. Bagian keempat berfungsi untuk membuat tiga variabel objek: objek2_1004 yang merujuk ke objek list yang sama persis dengan objek1_1004, dan objek3_1004 yang merupakan salinan (.copy()) dengan isi sama tapi objek berbeda di memori.
# 5. Bagian kelima berfungsi untuk menguji operator identitas is (mengecek apakah dua variabel menunjuk ke objek yang sama persis di memori) antara objek1_1004 dan objek2_1004.
# 6. Bagian keenam berfungsi untuk menguji operator identitas is not antara objek1_1004 dan objek3_1004.
# 7. Bagian ketujuh berfungsi untuk membandingkan langsung antara operator identitas (is, mengecek objek yang sama) dan operator kesetaraan (==, mengecek isi/nilai yang sama) pada objek1_1004 dan objek3_1004, untuk menunjukkan bahwa keduanya bisa berbeda hasil walau isinya sama.

# %% [markdown]
# ### 2.2.6 Program "perbandingan_2611531004"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Buat file dengan nama perbandingan_2611531004.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1004
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# program operator perbandingan dalam Phyton

angka1_1004 = int(input("Input angka-1: "))
angka2_1004 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_1004 = angka1_1004 > angka2_1004
print("\nOperator lebih besar dari")
print("Angka1 > Angka2 =", hasil_1004)

# Lebih kecil dari
hasil_1004 = angka1_1004 < angka2_1004
print("\nOperator lebih kecil dari")
print("Angka1 < Angka2 =", hasil_1004)

# Lebih besar dari atau sama dengan
hasil_1004 = angka1_1004 >= angka2_1004
print("\nOperator lebih besar dari atau sama dengan")
print("Angka1 >= Angka2 =", hasil_1004)

# Lebih kecil dari atau sama dengan
hasil_1004 = angka1_1004 <= angka2_1004
print("\nOperator lebih kecil dari atau sama dengan")
print("Angka1 <= Angka2 =", hasil_1004)

# Sama dengan
hasil_1004 = angka1_1004 == angka2_1004
print("\nOperator sama dengan")
print("Angka1 == Angka2 =", hasil_1004)

# Tidak sama dengan
hasil_1004 = angka1_1004 != angka2_1004
print("\nOperator tidak sama dengan")
print("Angka1 != Angka2 =", hasil_1004)

# Tambahan: perbandingan berantai dalam Phyton
hasil_1004 = 0 < angka1_1004 < 100
print("\nPerbandingan berantai")
print("0 < Angka1 < 100 =", hasil_1004)

hasil_1004 = 0 < angka2_1004 < 100
print("0 < Angka2 < 100 =", hasil_1004)
# Out:
# Operator lebih besar dari
# Angka1 > Angka2 = True
#
# Operator lebih kecil dari
# Angka1 < Angka2 = False
#
# Operator lebih besar dari atau sama dengan
# Angka1 >= Angka2 = True
#
# Operator lebih kecil dari atau sama dengan
# Angka1 <= Angka2 = False
#
# Operator sama dengan
# Angka1 == Angka2 = False
#
# Operator tidak sama dengan
# Angka1 != Angka2 = True
#
# Perbandingan berantai
# 0 < Angka1 < 100 = True
# 0 < Angka2 < 100 = True

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_perbandingan.jpg" width="400"><br>
# <em>Gambar 2.6 : Output Program</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk menerima dua input angka dari pengguna.
# 2. Bagian kedua sampai keenam berfungsi untuk menghitung operator perbandingan dasar: lebih besar dari (>), lebih kecil dari (<), lebih besar sama dengan (>=), lebih kecil sama dengan (<=), sama dengan (==), dan tidak sama dengan (!=), masing-masing menghasilkan nilai boolean.
# 3. Bagian terakhir berfungsi untuk mendemonstrasikan perbandingan berantai (chained comparison), fitur khas Python yang memungkinkan penulisan 0 < angka1_1004 < 100 untuk mengecek apakah suatu angka berada dalam rentang tertentu sekaligus.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :** Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas2_2611531004"

# %%
"""
Tugas Praktikum 3 - Algoritma Pemrograman
Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
NIM        : 2611531004
Catatan    : Seluruh variabel utama diakhiri dengan 4 digit terakhir NIM (_1004)
"""

# =========================================================
# DAFTAR PROMO YANG TERSEDIA DI TOKO
# =========================================================
daftar_promo_1004 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

print("=== SISTEM TRANSAKSI TOKO ===")

# =========================================================
# 1. INPUT DATA PELANGGAN (bukan nilai hardcode)
# =========================================================
nama_1004 = input("Masukkan Nama Pelanggan : ")
status_1004 = input("Masukkan Status Pelanggan (member/nonmember) : ").strip().lower()
total_1004 = float(input("Masukkan Total Belanja : "))
jumlah_1004 = int(input("Masukkan Jumlah Barang : "))
promo_1004 = input("Masukkan Kode Promo : ").strip().upper()

# =========================================================
# 2. OPERATOR PERBANDINGAN (comparison operator)
#    Menentukan apakah pelanggan memenuhi syarat diskon/promo
# =========================================================
syarat_belanja_1004 = total_1004 >= 200000      # True/False
syarat_barang_1004 = jumlah_1004 >= 3           # True/False
adalah_member_1004 = status_1004 == "member"    # True/False

# =========================================================
# 3. OPERATOR KEANGGOTAAN (membership operator: in / not in)
#    Mengecek apakah kode promo pelanggan valid
# =========================================================
promo_tersedia_1004 = promo_1004 in daftar_promo_1004
promo_tidak_dikenal_1004 = promo_1004 not in daftar_promo_1004

# =========================================================
# 4. OPERATOR LOGIKA (and, or, not)
#    Menggabungkan beberapa syarat sekaligus
# =========================================================
# Diskon member: pelanggan berstatus member DAN total belanja memenuhi syarat minimum
diskon_member_1004 = adalah_member_1004 and syarat_belanja_1004

# Promo didapat jika: (diskon member ATAU jumlah barang memenuhi syarat) DAN kode promo valid
dapat_promo_1004 = (diskon_member_1004 or syarat_barang_1004) and promo_tersedia_1004

# Contoh penggunaan "not": pelanggan non-member ditandai lewat negasi status member
bukan_member_1004 = not adalah_member_1004

# =========================================================
# 5. OPERATOR ARITMATIKA (+, -, *, /, %)
#    Menghitung besaran transaksi
# =========================================================
persen_diskon_1004 = 0.10 if dapat_promo_1004 else 0.0   # 10% jika dapat promo
diskon_1004 = total_1004 * persen_diskon_1004             # perkalian
subtotal_1004 = total_1004 - diskon_1004                  # pengurangan
ratarata_1004 = subtotal_1004 / jumlah_1004                # pembagian
sisabagi_1004 = jumlah_1004 % 3                            # modulus (sisa bagi jumlah barang oleh 3)

# =========================================================
# 6. OPERATOR PENUGASAN (assignment & augmented assignment)
#    Menghitung poin loyalitas dan ongkos kirim
# =========================================================
poin_1004 = 0
poin_1004 += jumlah_1004 * 10          # augmented assignment: tambah poin dari jumlah barang
if adalah_member_1004:
    poin_1004 += 20                    # bonus poin khusus member

ongkir_1004 = 15000
if promo_1004 == "GRATISONGKIR" and promo_tersedia_1004:
    ongkir_1004 -= 15000               # augmented assignment: ongkir jadi gratis

bayar_1004 = subtotal_1004
bayar_1004 += ongkir_1004              # augmented assignment: total akhir + ongkir

# =========================================================
# 7. OPERATOR IDENTITAS (is / is not)
#    Membedakan identitas objek vs kesamaan nilai (==)
# =========================================================
keranjang_a_1004 = [nama_1004, promo_1004]
keranjang_b_1004 = [nama_1004, promo_1004]   # objek baru, isi sama persis dengan keranjang_a
keranjang_c_1004 = keranjang_a_1004          # merujuk ke objek yang SAMA dengan keranjang_a

identitas_beda_objek_1004 = keranjang_a_1004 is keranjang_b_1004      # False -> objek berbeda
identitas_sama_objek_1004 = keranjang_a_1004 is keranjang_c_1004      # True  -> objek sama
nilai_sama_1004 = keranjang_a_1004 == keranjang_b_1004                # True  -> isi/nilai sama

# =========================================================
# 8. OPERATOR BITWISE (&, |, ^, <<)
#    Menyusun kode status transaksi 4-bit:
#    0001 = member | 0010 = belanja>=200rb | 0100 = barang>=3 | 1000 = promo tersedia
# =========================================================
bit_member_1004 = 0b0001 if adalah_member_1004 else 0b0000
bit_belanja_1004 = 0b0010 if syarat_belanja_1004 else 0b0000
bit_barang_1004 = 0b0100 if syarat_barang_1004 else 0b0000
bit_promo_1004 = 0b1000 if promo_tersedia_1004 else 0b0000

# OR (|) menggabungkan seluruh kondisi menjadi satu kode status transaksi
kode_status_1004 = bit_member_1004 | bit_belanja_1004 | bit_barang_1004 | bit_promo_1004

# AND (&) memeriksa apakah bit tertentu aktif (dipakai untuk hak akses)
cek_member_1004 = kode_status_1004 & 0b0001
cek_promo_1004 = kode_status_1004 & 0b1000

# XOR (^) membandingkan kode transaksi pelanggan dengan kode referensi toko
kode_referensi_1004 = 0b1011  # kode acuan: member + barang cukup + promo, tanpa syarat belanja
selisih_status_1004 = kode_status_1004 ^ kode_referensi_1004

# Bonus: left shift, menaikkan "level" kode status untuk keperluan logging internal
kode_shift_1004 = kode_status_1004 << 1

# Hak akses pelanggan ditentukan dari hasil operator bitwise di atas
member_access_1004 = cek_member_1004 != 0
promo_access_1004 = cek_promo_1004 != 0
free_shipping_access_1004 = (promo_1004 == "GRATISONGKIR") and promo_tersedia_1004

# =========================================================
# CETAK HASIL
# =========================================================
print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan   : {nama_1004}")
print(f"Status Pelanggan : {status_1004}")
print(f"Total Belanja    : Rp{total_1004:.0f}")
print(f"Jumlah Barang    : {jumlah_1004}")
print(f"Kode Promo       : {promo_1004}")

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000       : {syarat_belanja_1004}")
print(f"Jumlah Barang >= 3        : {syarat_barang_1004}")
print(f"Status Member             : {adalah_member_1004}")
print(f"Kode Promo Tersedia       : {promo_tersedia_1004}")
print(f"Mendapatkan Diskon Member : {diskon_member_1004}")
print(f"Mendapatkan Promo         : {dapat_promo_1004}")

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                 : Rp{diskon_1004:.0f}")
print(f"Ongkos Kirim            : Rp{ongkir_1004:.0f}")
print(f"Total Pembayaran        : Rp{bayar_1004:.0f}")
print(f"Rata-rata Harga Barang  : Rp{ratarata_1004:.0f}")
print(f"Sisa Bagi (jumlah % 3)  : {sisabagi_1004}")
print(f"Poin Loyalitas          : {poin_1004}")

print("\n=== OPERATOR IDENTITAS (DEMO) ===")
print(f"keranjang_a is keranjang_b (objek beda)  : {identitas_beda_objek_1004}")
print(f"keranjang_a is keranjang_c (objek sama)  : {identitas_sama_objek_1004}")
print(f"keranjang_a == keranjang_b (nilai sama)  : {nilai_sama_1004}")

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print(f"{bin(bit_member_1004)[2:].zfill(4)} | {bin(bit_belanja_1004)[2:].zfill(4)} | "
      f"{bin(bit_barang_1004)[2:].zfill(4)} | {bin(bit_promo_1004)[2:].zfill(4)}")
print(f"Kode Biner  : {bin(kode_status_1004)[2:].zfill(4)}")
print(f"Kode Desimal: {kode_status_1004}")

print("\n=== Pemeriksaan Status (AND) ===")
print("Cek Member")
print(f"{bin(kode_status_1004)[2:].zfill(4)} & 0001")
print(f"Hasil Biner  : {bin(cek_member_1004)[2:].zfill(4)}")
print(f"Hasil Desimal: {cek_member_1004}")

print("\nCek Promo")
print(f"{bin(kode_status_1004)[2:].zfill(4)} & 1000")
print(f"Hasil Biner  : {bin(cek_promo_1004)[2:].zfill(4)}")
print(f"Hasil Desimal: {cek_promo_1004}")

print("\n=== Perbandingan Status (XOR) ===")
print(f"Kode Transaksi : {bin(kode_status_1004)[2:].zfill(4)}")
print(f"Kode Referensi : {bin(kode_referensi_1004)[2:].zfill(4)}")
print(f"{bin(kode_status_1004)[2:].zfill(4)} ^ {bin(kode_referensi_1004)[2:].zfill(4)}")
print(f"Hasil Biner  : {bin(selisih_status_1004)[2:].zfill(4)}")
print(f"Hasil Desimal: {selisih_status_1004}")

print("\n=== Shift (Bonus) ===")
print(f"{bin(kode_status_1004)[2:].zfill(4)} << 1")
print(f"Hasil Biner  : {bin(kode_shift_1004)[2:].zfill(5)}")
print(f"Hasil Desimal: {kode_shift_1004}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Hak Akses       : {bin(kode_status_1004)[2:].zfill(4)}")
print(f"Member Access        : {member_access_1004}")
print(f"Promo Access         : {promo_access_1004}")
print(f"Free Shipping Access : {free_shipping_access_1004}")

print("\n=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
# === DATA TRANSAKSI ===
# Nama Pelanggan   : fabian
# Status Pelanggan : member
# Total Belanja    : Rp800000
# Jumlah Barang    : 12
# Kode Promo       : HEMAT20
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000       : True
# Jumlah Barang >= 3        : True
# Status Member             : True
# Kode Promo Tersedia       : True
# Mendapatkan Diskon Member : True
# Mendapatkan Promo         : True
#
# === HASIL PERHITUNGAN ===
# Diskon                 : Rp80000
# Ongkos Kirim            : Rp15000
# Total Pembayaran        : Rp735000
# Rata-rata Harga Barang  : Rp60000
# Sisa Bagi (jumlah % 3)  : 0
# Poin Loyalitas          : 140
#
# === OPERATOR IDENTITAS (DEMO) ===
# keranjang_a is keranjang_b (objek beda)  : False
# keranjang_a is keranjang_c (objek sama)  : True
# keranjang_a == keranjang_b (nilai sama)  : True
#
# === OPERASI BITWISE ===
# === Kode Status Transaksi ===
# 0001 | 0010 | 0100 | 1000
# Kode Biner  : 1111
# Kode Desimal: 15
#
# ...

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas1.jpg" width="400"><br>
# <img src="images/output_tugas2.jpg" width="400"><br>
# <img src="images/output_tugas3.jpg" width="400"><br>
# <em>Gambar 2.7 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas3_2611531004.py dirancang untuk mensimulasikan proses transaksi di sebuah toko sekaligus melakukan validasi hak akses pelanggan berdasarkan status dan promo yang dimiliki. Alur programnya sebagai berikut:
#
# 1. **Data Promo Toko:** Daftar kode promo yang berlaku (daftar_promo_1004) disimpan dalam bentuk list berisi tiga kode: HEMAT10, HEMAT20, dan GRATISONGKIR.
# 2. **Input Data Pelanggan:** Program meminta lima data dari pengguna melalui input(): nama pelanggan, status keanggotaan (member/nonmember), total belanja (dikonversi ke float), jumlah barang (dikonversi ke int), dan kode promo yang digunakan.
# 3. **Operator Perbandingan:** Tiga kondisi dasar dievaluasi menggunakan operator perbandingan (>=, ==), yaitu apakah total belanja mencapai minimum Rp200.000, apakah jumlah barang minimal 3, dan apakah status pelanggan adalah member.
# 4. **Operator Keanggotaan (in / not in):** Program mengecek keabsahan kode promo dengan melihat apakah kode yang dimasukkan pelanggan terdapat di dalam daftar_promo_1004.
# 5. **Operator Logika (and, or, not):** Beberapa syarat digabungkan untuk menentukan kelayakan diskon. Diskon member berlaku jika pelanggan member dan total belanja memenuhi syarat. Promo didapat jika (diskon member atau jumlah barang cukup) dan kode promo valid. Operator not digunakan untuk menandai status non-member.
# 6. **Operator Aritmatika (+, -, *, /, %):** Nilai diskon dihitung dari perkalian total belanja dengan persentase diskon (10% jika dapat promo), lalu subtotal dihitung dengan pengurangan. Rata-rata harga barang diperoleh dari pembagian subtotal dengan jumlah barang, dan sisa bagi jumlah barang dengan 3 dihitung menggunakan modulus.
# 7. **Operator Penugasan (+=, -=):** Poin loyalitas dihitung bertahap menggunakan augmented assignment, ditambah bonus 20 poin jika member. Ongkos kirim dikurangi menjadi gratis jika kode promo GRATISONGKIR valid, dan total pembayaran akhir dijumlahkan dari subtotal ditambah ongkir.
# 8. **Operator Identitas (is / is not):** Tiga variabel list (keranjang_a, keranjang_b, keranjang_c) digunakan untuk mendemonstrasikan perbedaan antara kesamaan nilai (==) dan kesamaan objek (is). keranjang_a dan keranjang_c merujuk objek yang sama (hasil is = True), sedangkan keranjang_a dan keranjang_b adalah objek berbeda meski isinya sama (hasil is = False, tapi == = True).
# 9. **Operator Bitwise (&, |, ^, <<):** Status transaksi direpresentasikan sebagai kode 4-bit, di mana setiap bit mewakili satu syarat (member, belanja cukup, barang cukup, promo tersedia). Operator OR (|) menggabungkan seluruh syarat menjadi satu kode status, operator AND (&) digunakan untuk memeriksa apakah bit tertentu aktif (dipakai sebagai dasar hak akses), operator XOR (^) membandingkan kode status pelanggan dengan kode referensi toko, dan operator left shift (<<) digunakan sebagai bonus untuk menaikkan level kode status untuk keperluan logging.
# 10. **Hak Akses Pelanggan:** Berdasarkan hasil operasi bitwise, program menentukan tiga jenis hak akses: akses member, akses promo, dan akses gratis ongkir, yang seluruhnya ditampilkan di akhir sebagai ringkasan status transaksi pelanggan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python menyediakan berbagai jenis operator, yaitu operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, dan bitwise, yang masing-masing memiliki peran penting dalam membangun logika program. Melalui studi kasus sistem simulasi transaksi dan validasi akses toko, mahasiswa dapat memahami bagaimana berbagai operator tersebut dapat diintegrasikan dalam satu alur program yang utuh, mulai dari perhitungan total pembayaran, validasi syarat diskon dan promo, hingga penentuan hak akses pelanggan menggunakan representasi bit.
#
# Pemahaman terhadap operator identitas (`is`) dan operator perbandingan (`==`) juga menjadi hal penting agar mahasiswa tidak keliru dalam membandingkan objek berdasarkan identitas maupun nilai. Selain itu, penerapan operator bitwise dalam merepresentasikan status pelanggan memberikan wawasan baru bagi mahasiswa mengenai cara kerja logika di level bit, yang menjadi bekal penting untuk mempelajari konsep pemrograman yang lebih kompleks di masa mendatang.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] A. Kadir, *Dasar Pemrograman Python 3*, Yogyakarta: Penerbit ANDI, 2018.
#
# [2] Python Software Foundation, "Expressions — Operators," *The Python Language Reference*, [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html. [Diakses 20 September 2026].
#
# [3] Jubilee Enterprise, *Python untuk Programmer Pemula*, Jakarta: PT. Elex Media Komputindo, 2023.
#
# [4] S. Chacon dan B. Straub, *Pro Git*, edisi Bahasa Indonesia, [Online]. Tersedia: https://git-scm.com/book/id/v2. [Diakses 10 September 2026].
